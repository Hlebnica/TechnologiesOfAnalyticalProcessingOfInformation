# %% [markdown]
# # Старостенок Дмитрий КЭ-403 - Поиск ассоциативных правил

# %% [markdown]
# Доработайте программу из задания Поиск частых наборов, чтобы она также выполняла поиск ассоциативных правил. Список результирующих правил должен выдаваться в удобочитаемом виде (антецедент→консеквент) с указанием поддержки и достоверности каждого правила. Дополнительные параметры программы: порог достоверности, способ упорядочивания результирующего списка наборов (по убыванию значения поддержки или лексикографическое).
#
# Проведите эксперименты на наборах из задания 1. В экспериментах Зафиксируйте значение пороговое значение поддержки (например, 10%), варьируйте пороговое значение достоверности (например, от 70% до 95% с шагом 5%).
#
# Выполните визуализацию полученных результатов в виде следующих диаграмм:
#  - сравнение быстродействия поиска правил на фиксированном наборе данных при изменяемом пороге достоверности;
#  - общее количество найденных правил на фиксированном наборе данных при изменяемом пороге достоверности.
#
# Подготовьте список правил, в которых антецедент и консеквент суммарно включают в себя не более семи объектов (разумное количество). Проанализируйте и изложите содержательный смысл полученного результата.
#
# Подготовьте отчет о выполнении задания и загрузите отчет в формате PDF в систему. Отчет должен представлять собой связный и структурированный документ со следующими разделами:
#  - формулировка задания;
#  - гиперссылка на каталог репозитория с исходными текстами, наборами данных и др. сопутствующими материалами;
#  - рисунки с результатами визуализации;
#  - пояснения, раскрывающие смысл полученных результатов.

# %%
import pandas as pd
import chardet
from mlxtend.preprocessing import TransactionEncoder
from mlxtend.frequent_patterns import apriori, association_rules
import time
import matplotlib.pyplot as plt

# %%
with open('baskets.csv', 'rb') as f:
    result = chardet.detect(f.read())

df = pd.read_csv('baskets.csv', encoding=result['encoding'])
df
# Out:
#                     креветки                  миндаль  \
# 0                  гамбургер              фрикадельки
# 1                      чатни                      NaN
# 2                    индейка                  авокадо
# 3           минеральная вода                   молоко
# 4     низкокалорийный йогурт                      NaN
# ...                      ...                      ...
# 7495         сливочное масло  низкокалорийный майонез
# 7496               гамбургер       замороженные овощи
# 7497                  курица                      NaN
# 7498                 эскалоп              зеленый чай
# 7499                    яйца       замороженный смузи
#
#                       авокадо           овощная смесь зеленый виноград  \
# 0                        яйца                     NaN              NaN
# 1                         NaN                     NaN              NaN
# 2                         NaN                     NaN              NaN
# 3     энергетический батончик                     рис      зеленый чай
# 4                         NaN                     NaN              NaN
# ...                       ...                     ...              ...
# 7495              свежий хлеб                     NaN              NaN
# 7496                     яйца           картофель-фри           журнал
# 7497                      NaN                     NaN              NaN
# 7498                      NaN                     NaN              NaN
# 7499                   йогурт  низкокалорийный йогурт              NaN
#
#      цельнозерновая мука батат творог энергетический напиток томатный сок  \
# 0                    NaN   NaN    NaN                    NaN          NaN
# 1                    NaN   NaN    NaN                    NaN          NaN
# 2                    NaN   NaN    NaN                    NaN          NaN
# 3                    NaN   NaN    NaN                    NaN          NaN
# 4                    NaN   NaN    NaN                    NaN          NaN
# ...                  ...   ...    ...                    ...          ...
# 7495                 NaN   NaN    NaN                    NaN          NaN
# 7496         зеленый чай   NaN    NaN                    NaN          NaN
# 7497                 NaN   NaN    NaN                    NaN          NaN
# 7498                 NaN   NaN    NaN                    NaN          NaN
# 7499                 NaN   NaN    NaN                    NaN          NaN
#
#      низкокалорийный йогурт зеленый чай  мед салат минеральная вода лосось  \
# 0                       NaN         NaN  NaN   NaN              NaN    NaN
# 1                       NaN         NaN  NaN   NaN              NaN    NaN
# 2                       NaN         NaN  NaN   NaN              NaN    NaN
# 3                       NaN         NaN  NaN   NaN              NaN    NaN
# 4                       NaN         NaN  NaN   NaN              NaN    NaN
# ...                     ...         ...  ...   ...              ...    ...
# 7495                    NaN         NaN  NaN   NaN              NaN    NaN
# 7496                    NaN         NaN  NaN   NaN              NaN    NaN
# 7497                    NaN         NaN  NaN   NaN              NaN    NaN
# 7498                    NaN         NaN  NaN   NaN              NaN    NaN
# 7499                    NaN         NaN  NaN   NaN              NaN    NaN
#
#      ягодный сок замороженный смузи шпинат  оливковое масло
# 0            NaN                NaN    NaN              NaN
# 1            NaN                NaN    NaN              NaN
# 2            NaN                NaN    NaN              NaN
# 3            NaN                NaN    NaN              NaN
# 4            NaN                NaN    NaN              NaN
# ...          ...                ...    ...              ...
# 7495         NaN                NaN    NaN              NaN
# 7496         NaN                NaN    NaN              NaN
# 7497         NaN                NaN    NaN              NaN
# 7498         NaN                NaN    NaN              NaN
# 7499         NaN                NaN    NaN              NaN
#
# [7500 rows x 20 columns]

# %%
from mlxtend.frequent_patterns import association_rules

def find_frequent_itemsets_and_association_rules(data, min_support, min_confidence, sort_by='support'):
    # Преобразование данных в список списков для подачи в метод fit
    transactions = data.values.tolist()

    # Удаление значений NaN из транзакций
    transactions = [[item for item in transaction if not pd.isnull(item)] for transaction in transactions]

    # Преобразование в разряженную матрицу
    te = TransactionEncoder()
    te_transform = te.fit(transactions).transform(transactions)
    transactions_matrix = pd.DataFrame(te_transform, columns=te.columns_)

    # Поиск частых наборов с помощью алгоритма Apriori
    frequent_itemsets = apriori(transactions_matrix, min_support=min_support, use_colnames=True)

    # Поиск ассоциативных правил
    rules = association_rules(frequent_itemsets, metric="confidence", min_threshold=min_confidence)
    rules["antecedent"] = rules["antecedents"].apply(lambda x: ', '.join(list(x)))
    rules["consequent"] = rules["consequents"].apply(lambda x: ', '.join(list(x)))
    rules = rules[["antecedent", "consequent", "support", "confidence"]]

    # Сортировка результатов
    if sort_by == 'support':
        frequent_itemsets = frequent_itemsets.sort_values(by='support', ascending=False)
        rules = rules.sort_values(by='support', ascending=False)
    elif sort_by == 'lexical':
        frequent_itemsets = frequent_itemsets.sort_values(by='itemsets')
        rules = rules.sort_values(by=['antecedent', 'consequent'])

    return frequent_itemsets, rules

# %%
# Проведем эксперименты
min_support = 0.002
min_confidence_values = [0.7, 0.75, 0.8, 0.85, 0.9, 0.95]

for min_confidence in min_confidence_values:
    frequent_itemsets, rules = find_frequent_itemsets_and_association_rules(df, min_support, min_confidence)
    
    # Вывод результатов в Jupyter Notebook
    display(f'Порог достоверности: {min_confidence}')
    display(pd.DataFrame(frequent_itemsets))
    display(pd.DataFrame(rules))
# Out:
# 'Порог достоверности: 0.7'
#        support                                           itemsets
# 47    0.238267                                 (минеральная вода)
# 42    0.188000                                         (макароны)
# 110   0.179733                                             (яйца)
# 28    0.170933                                    (картофель-фри)
# 104   0.163867                                          (шоколад)
# ...        ...                                                ...
# 233   0.002000                       (блинчики, соус для барбекю)
# 242   0.002000                            (блинчики, фрикадельки)
# 2395  0.002000             (минеральная вода, молоко, шампанское)
# 1727  0.002000       (низкокалорийный йогурт, говяжий фарш, яйца)
# 2716  0.002000  (макароны, шоколад, замороженные овощи, молоко...
#
# [2717 rows x 2 columns]
#                                            antecedent        consequent  \
# 0                               эскалоп, грибной соус          макароны
# 9                     суп, замороженные овощи, молоко  минеральная вода
# 11                 макароны, растительное масло, яйца  минеральная вода
# 10       шоколад, замороженные овощи, оливковое масло  минеральная вода
# 13                      молоко, оливковое масло, яйца  минеральная вода
# 2                       обезжиренное молоко, макароны  минеральная вода
# 6          замороженные овощи, креветки, говяжий фарш          макароны
# 4              макароны, блинчики, растительное масло  минеральная вода
# 5                             суп, макароны, блинчики  минеральная вода
# 1                               красное вино, индейка  минеральная вода
# 3                         рис, блинчики, говяжий фарш  минеральная вода
# 8       замороженные овощи, оливковое масло, помидоры          макароны
# 12                              рис, молоко, помидоры          макароны
# 7                 индейка, замороженные овощи, молоко  минеральная вода
# 14  шоколад, замороженные овощи, молоко, говяжий фарш  минеральная вода
# 15    замороженные овощи, шоколад, макароны, креветки  минеральная вода
#
#      support  confidence
# 0   0.004267    0.744186
# 9   0.003067    0.766667
# 11  0.003067    0.718750
# 10  0.002800    0.700000
# 13  0.002667    0.714286
# 2   0.002533    0.730769
# 6   0.002533    0.791667
# 4   0.002267    0.739130
# 5   0.002267    0.772727
# 1   0.002133    0.727273
# 3   0.002133    0.842105
# 8   0.002133    0.842105
# 12  0.002133    0.800000
# 7   0.002000    0.750000
# 14  0.002000    0.750000
# 15  0.002000    0.882353
# 'Порог достоверности: 0.75'
#        support                                           itemsets
# 47    0.238267                                 (минеральная вода)
# 42    0.188000                                         (макароны)
# 110   0.179733                                             (яйца)
# 28    0.170933                                    (картофель-фри)
# 104   0.163867                                          (шоколад)
# ...        ...                                                ...
# 233   0.002000                       (блинчики, соус для барбекю)
# 242   0.002000                            (блинчики, фрикадельки)
# 2395  0.002000             (минеральная вода, молоко, шампанское)
# 1727  0.002000       (низкокалорийный йогурт, говяжий фарш, яйца)
# 2716  0.002000  (макароны, шоколад, замороженные овощи, молоко...
#
# [2717 rows x 2 columns]
#                                           antecedent        consequent  \
# 5                    суп, замороженные овощи, молоко  минеральная вода
# 2         замороженные овощи, креветки, говяжий фарш          макароны
# 1                            суп, макароны, блинчики  минеральная вода
# 0                        рис, блинчики, говяжий фарш  минеральная вода
# 4      замороженные овощи, оливковое масло, помидоры          макароны
# 6                              рис, молоко, помидоры          макароны
# 3                индейка, замороженные овощи, молоко  минеральная вода
# 7  шоколад, замороженные овощи, молоко, говяжий фарш  минеральная вода
# 8    замороженные овощи, шоколад, макароны, креветки  минеральная вода
#
#     support  confidence
# 5  0.003067    0.766667
# 2  0.002533    0.791667
# 1  0.002267    0.772727
# 0  0.002133    0.842105
# 4  0.002133    0.842105
# 6  0.002133    0.800000
# 3  0.002000    0.750000
# 7  0.002000    0.750000
# 8  0.002000    0.882353
# 'Порог достоверности: 0.8'
#        support                                           itemsets
# 47    0.238267                                 (минеральная вода)
# 42    0.188000                                         (макароны)
# 110   0.179733                                             (яйца)
# 28    0.170933                                    (картофель-фри)
# 104   0.163867                                          (шоколад)
# ...        ...                                                ...
# 233   0.002000                       (блинчики, соус для барбекю)
# 242   0.002000                            (блинчики, фрикадельки)
# 2395  0.002000             (минеральная вода, молоко, шампанское)
# 1727  0.002000       (низкокалорийный йогурт, говяжий фарш, яйца)
# 2716  0.002000  (макароны, шоколад, замороженные овощи, молоко...
#
# [2717 rows x 2 columns]
#                                         antecedent        consequent  \
# 0                      рис, блинчики, говяжий фарш  минеральная вода
# 1    замороженные овощи, оливковое масло, помидоры          макароны
# 2                            рис, молоко, помидоры          макароны
# 3  замороженные овощи, шоколад, макароны, креветки  минеральная вода
#
#     support  confidence
# 0  0.002133    0.842105
# 1  0.002133    0.842105
# 2  0.002133    0.800000
# 3  0.002000    0.882353
# 'Порог достоверности: 0.85'
#        support                                           itemsets
# 47    0.238267                                 (минеральная вода)
# 42    0.188000                                         (макароны)
# 110   0.179733                                             (яйца)
# 28    0.170933                                    (картофель-фри)
# 104   0.163867                                          (шоколад)
# ...        ...                                                ...
# 233   0.002000                       (блинчики, соус для барбекю)
# 242   0.002000                            (блинчики, фрикадельки)
# 2395  0.002000             (минеральная вода, молоко, шампанское)
# 1727  0.002000       (низкокалорийный йогурт, говяжий фарш, яйца)
# 2716  0.002000  (макароны, шоколад, замороженные овощи, молоко...
#
# [2717 rows x 2 columns]
#                                         antecedent        consequent  support  \
# 0  замороженные овощи, шоколад, макароны, креветки  минеральная вода    0.002
#
#    confidence
# 0    0.882353
# 'Порог достоверности: 0.9'
#        support                                           itemsets
# 47    0.238267                                 (минеральная вода)
# 42    0.188000                                         (макароны)
# 110   0.179733                                             (яйца)
# 28    0.170933                                    (картофель-фри)
# 104   0.163867                                          (шоколад)
# ...        ...                                                ...
# 233   0.002000                       (блинчики, соус для барбекю)
# 242   0.002000                            (блинчики, фрикадельки)
# 2395  0.002000             (минеральная вода, молоко, шампанское)
# 1727  0.002000       (низкокалорийный йогурт, говяжий фарш, яйца)
# 2716  0.002000  (макароны, шоколад, замороженные овощи, молоко...
#
# [2717 rows x 2 columns]
# Empty DataFrame
# Columns: [antecedent, consequent, support, confidence]
# Index: []
# 'Порог достоверности: 0.95'
#        support                                           itemsets
# 47    0.238267                                 (минеральная вода)
# 42    0.188000                                         (макароны)
# 110   0.179733                                             (яйца)
# 28    0.170933                                    (картофель-фри)
# 104   0.163867                                          (шоколад)
# ...        ...                                                ...
# 233   0.002000                       (блинчики, соус для барбекю)
# 242   0.002000                            (блинчики, фрикадельки)
# 2395  0.002000             (минеральная вода, молоко, шампанское)
# 1727  0.002000       (низкокалорийный йогурт, говяжий фарш, яйца)
# 2716  0.002000  (макароны, шоколад, замороженные овощи, молоко...
#
# [2717 rows x 2 columns]
# Empty DataFrame
# Columns: [antecedent, consequent, support, confidence]
# Index: []

# %%
def plot_performance_vs_confidence(min_support, min_confidence_values):
    # Список для хранения времени выполнения
    execution_times = []

    for min_confidence in min_confidence_values:
        start_time = time.time()
        frequent_itemsets, rules = find_frequent_itemsets_and_association_rules(df, min_support, min_confidence)
        execution_time = time.time() - start_time
        execution_times.append(execution_time)

    # Создаем диаграмму
    plt.figure(figsize=(10, 6))
    plt.plot(min_confidence_values, execution_times, marker='o')
    plt.xlabel('Порог достоверности')
    plt.ylabel('Время выполнения (сек)')
    plt.title('Сравнение быстродействия поиска правил при изменении порога достоверности')
    plt.grid(True)
    plt.show()

def plot_rule_count_vs_confidence(min_support, min_confidence_values):
    # Список для хранения количества правил
    rule_counts = []

    for min_confidence in min_confidence_values:
        frequent_itemsets, rules = find_frequent_itemsets_and_association_rules(df, min_support, min_confidence)
        rule_counts.append(len(rules))

    # Создаем диаграмму
    plt.figure(figsize=(10, 6))
    plt.plot(min_confidence_values, rule_counts, marker='o', color='r')
    plt.xlabel('Порог достоверности')
    plt.ylabel('Количество правил')
    plt.title('Общее количество найденных правил при изменении порога достоверности')
    plt.grid(True)
    plt.show()

# %%
# Настройки для экспериментов
min_support = 0.002
min_confidence_values = [0.7, 0.75, 0.8, 0.85, 0.9, 0.95]

# Визуализация
plot_performance_vs_confidence(min_support, min_confidence_values)
plot_rule_count_vs_confidence(min_support, min_confidence_values)

# %%
# Настройки для экспериментов
min_support = 0.002
min_confidence = 0.65

# Найдем все частые наборы и ассоциативные правила
frequent_itemsets, rules = find_frequent_itemsets_and_association_rules(df, min_support, min_confidence)

# Отфильтруем правила, где количество элементов в антецеденте и консеквенте не превышает семь
filtered_rules = rules[(rules['antecedent'].apply(lambda x: len(x.split(', '))) + rules['consequent'].apply(lambda x: len(x.split(', '))) <= 7)]

# Выведем отфильтрованные правила
print("Правила, в которых антецедент и консеквент суммарно включают в себя не более семи объектов:")
filtered_rules
# Out:
# Правила, в которых антецедент и консеквент суммарно включают в себя не более семи объектов:
#                                            antecedent          consequent  \
# 2                               эскалоп, грибной соус            макароны
# 13           замороженные овощи, молоко, говяжий фарш    минеральная вода
# 19        замороженные овощи, молоко, оливковое масло    минеральная вода
# 20                    суп, замороженные овощи, молоко    минеральная вода
# 15                        рис, макароны, говяжий фарш    минеральная вода
# 23                 макароны, растительное масло, яйца    минеральная вода
# 1                                хлопья, говяжий фарш            макароны
# 21       шоколад, замороженные овощи, оливковое масло    минеральная вода
# 26                      молоко, оливковое масло, яйца    минеральная вода
# 17                  замороженные овощи, рис, макароны    минеральная вода
# 8                          протеиновый батончик, яйца    минеральная вода
# 12         замороженные овощи, креветки, говяжий фарш            макароны
# 22                           макароны, молоко, лосось    минеральная вода
# 5                       обезжиренное молоко, макароны    минеральная вода
# 11                            суп, макароны, блинчики    минеральная вода
# 10             макароны, блинчики, растительное масло    минеральная вода
# 24                                суп, макароны, яйца    минеральная вода
# 0                              красное вино, блинчики    минеральная вода
# 25                              рис, молоко, помидоры            макароны
# 14  минеральная вода, растительное масло, говяжий ...            макароны
# 18      замороженные овощи, оливковое масло, помидоры            макароны
# 9                         рис, блинчики, говяжий фарш    минеральная вода
# 4                               красное вино, индейка    минеральная вода
# 3                                  помидоры, пармезан  замороженные овощи
# 16                индейка, замороженные овощи, молоко    минеральная вода
# 7                            оливковое масло, хот-дог    минеральная вода
# 6                             хлопья, оливковое масло            макароны
# 27  шоколад, замороженные овощи, молоко, говяжий фарш    минеральная вода
# 28    замороженные овощи, шоколад, макароны, креветки    минеральная вода
#
#      support  confidence
# 2   0.004267    0.744186
# 13  0.003733    0.651163
# 19  0.003333    0.694444
# 20  0.003067    0.766667
# 15  0.003067    0.657143
# 23  0.003067    0.718750
# 1   0.003067    0.676471
# 21  0.002800    0.700000
# 26  0.002667    0.714286
# 17  0.002667    0.666667
# 8   0.002667    0.689655
# 12  0.002533    0.791667
# 22  0.002533    0.678571
# 5   0.002533    0.730769
# 11  0.002267    0.772727
# 10  0.002267    0.739130
# 24  0.002267    0.653846
# 0   0.002267    0.653846
# 25  0.002133    0.800000
# 14  0.002133    0.666667
# 18  0.002133    0.842105
# 9   0.002133    0.842105
# 4   0.002133    0.727273
# 3   0.002133    0.666667
# 16  0.002000    0.750000
# 7   0.002000    0.652174
# 6   0.002000    0.681818
# 27  0.002000    0.750000
# 28  0.002000    0.882353
